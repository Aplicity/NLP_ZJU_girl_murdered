# %%
import json
import requests
import pandas as pd
import time
import random

# %%
url = 'https://comment.news.163.com/api/v1/products/a2869674571f77b5a0867c3d71db5856/threads/E0RR7QHH0001899O/comments/newList?offset='
    
print(url)
# Out:
# https://comment.news.163.com/api/v1/products/a2869674571f77b5a0867c3d71db5856/threads/E0RR7QHH0001899O/comments/newList?offset=

# %%
commentIds = []  # 评论ID
is_anonymous = []  # 是否匿名
contents = []   # 评论
createTimes = [] # 评论时间
favCounts = []  # 收藏数
IPs = []    # ip
shareCounts = []  # 分享数
againsts = []  # 反对数
votes = []  # 赞成数
sources = []
isDels = []  # 是否删帖
siteNames = []
buildLevels = []  # 评论的层数

user_locations = [] # 用户的位置
user_IDs = []  # 用户ID

pages = []
inds = []

try:
    for page in range(2000):
        URL = url + str(page)
        r = requests.get(URL).text
        json_dict = json.loads(r)
        cmt_dict = json_dict['comments']
        for ind, Id in enumerate(cmt_dict.keys()):
            pages.append(page)
            inds.append(ind)
            commentIds.append(Id)                            # 评论ID
            user_IDs.append(cmt_dict[Id]['user']['userId'])  # 用户ID
            is_anonymous.append(cmt_dict[Id]['anonymous'])   # 是否匿名
            contents.append(cmt_dict[Id]['content'])         # 评论
            createTimes.append(cmt_dict[Id]['createTime'])   # 评论时间
            favCounts.append(cmt_dict[Id]['favCount'])       # 喜欢数
            IPs.append(cmt_dict[Id]['ip'])                   # ip
            shareCounts.append(cmt_dict[Id]['shareCount'])   # 分享数
            againsts.append(cmt_dict[Id]['against'])         # 反对数
            votes.append(cmt_dict[Id]['vote'])               # 赞成数
            sources.append(cmt_dict[Id]['source'])  
            isDels.append(cmt_dict[Id]['isDel'])             # 是否删帖
            siteNames.append(cmt_dict[Id]['siteName']) 
            buildLevels.append(cmt_dict[Id]['buildLevel'])   # 评论的层数
            user_locations.append(cmt_dict[Id]['user']['location']) # 用户的位置
    
        if page % 100 == 0:
            time.sleep(random.random()) # 每怕一页随机休眠1或2秒，避免对服务器造型干扰
            print('正在爬取第{}页的数据'.format(page))
except:
    pass
print('Done')
# Out:
# 正在爬取第0页的数据
# 正在爬取第100页的数据
# 正在爬取第200页的数据
# 正在爬取第300页的数据
# 正在爬取第400页的数据
# 正在爬取第500页的数据
# 正在爬取第600页的数据
# 正在爬取第700页的数据
# 正在爬取第800页的数据
# 正在爬取第900页的数据
# 正在爬取第1000页的数据
# 正在爬取第1100页的数据
# 正在爬取第1200页的数据
# 正在爬取第1300页的数据
# 正在爬取第1400页的数据
# 正在爬取第1500页的数据
# 正在爬取第1600页的数据
# 正在爬取第1700页的数据
# 正在爬取第1800页的数据
# 正在爬取第1900页的数据
# Done

# %%
df = pd.DataFrame({'commentIds':commentIds, 'user_IDs':user_IDs,
                  'is_anonymous':is_anonymous, 'contents':contents, 'createTimes':createTimes,
                  'favCounts':favCounts, 'IPs':IPs, 'shareCounts':shareCounts, 'againsts':againsts,
                  'votes':votes, 'sources':sources, 'isDels':isDels, 'siteNames':siteNames,
                  'buildLevels':buildLevels, 'user_locations':user_locations })

# %%
data = df.drop_duplicates()
data.to_csv('data.csv', index = None)

# %%
data
# Out:
#               IPs  againsts  buildLevels  commentIds  \
# 0     117.136.*.*         0            6   331532417
# 1     113.102.*.*         1            2   330898778
# 2       116.5.*.*         0            1   331615846
# 3      222.74.*.*         1            1   330656583
# 4       27.38.*.*         0            7   331810882
# 5     122.237.*.*         0            6   330829609
# 6     117.161.*.*         0            5   333625983
# 7       14.24.*.*         0            1   330799108
# 8      112.10.*.*         0            7   331616219
# 9      60.178.*.*         3            2   330659977
# 10     171.44.*.*         0            1   332001728
# 11    114.252.*.*         1            2   330680892
# 12      221.2.*.*         0            1   333307295
# 13     112.65.*.*         0           12   330853766
# 14     223.72.*.*         0            1   330672476
# 15     180.97.*.*         0            8   330963620
# 16    122.238.*.*        18            1   330650629
# 17    114.252.*.*         0            6   330686233
# 18    171.217.*.*         0            6   333678899
# 19     112.17.*.*         0            9   331968738
# 20      221.2.*.*         0            1   333307316
# 21     125.71.*.*         0            2   330807846
# 22     125.85.*.*         0            7   331620494
# 23    119.114.*.*         9            2   330652418
# 24     112.10.*.*         0           13   331623041
# 25     112.10.*.*         0            7   331610922
# 26    116.226.*.*         0            1   331590537
# 27    111.182.*.*         0            2   331587578
# 28     112.10.*.*         1            1   330647997
# 29    116.226.*.*         0            3   331581646
# ...           ...       ...          ...         ...
# 2203  112.224.*.*         0            1   330649198
# 2204  211.138.*.*         0            1   330649196
# 2205    112.0.*.*         0            1   330649194
# 2206  122.233.*.*         0            1   330646981
# 2207    36.24.*.*         0            1   330648595
# 2208   58.101.*.*         0            1   330648591
# 2209  183.206.*.*         0            1   330648586
# 2210  115.196.*.*         0            1   330648585
# 2211    112.5.*.*         0            1   330648584
# 2212  111.206.*.*         0            1   330646972
# 2213  180.125.*.*         0            1   330648583
# 2214   112.17.*.*         0            1   330646969
# 2215  180.137.*.*         0            1   330646967
# 2216   58.100.*.*         0            1   330649183
# 2217  183.155.*.*         0            1   330648579
# 2218  180.108.*.*         0            1   330646966
# 2219  115.197.*.*         0            1   330646963
# 2220     1.61.*.*         0            1   330646960
# 2221   125.77.*.*         0            1   330648570
# 2222  125.118.*.*         0            1   330649172
# 2223   60.186.*.*         0            1   330646953
# 2224   124.91.*.*         0            1   330649169
# 2225  115.205.*.*         0            1   330649165
# 2226   101.44.*.*         0            1   330649159
# 2227   112.10.*.*         0            1   330649158
# 2228    1.198.*.*         0            1   330646944
# 2229   113.81.*.*         0            1   330649141
# 2230    58.40.*.*         0            1   330646935
# 2231  222.212.*.*         0            1   330646933
# 2232  123.185.*.*         0            1   330649129
#
#                                                contents          createTimes  \
# 0                                            劫匪说：没事，俺也有  2018-11-19 10:15:38
# 1     有些个妇人，以为自个本事大，有魄力，动不动还瞧不起男人，不听劝告，自以为是，自以为有个性，有...  2018-11-18 12:17:22
# 2                                               广西人[喷水]  2018-11-19 12:19:03
# 2208                                               这。。。  2018-11-18 00:14:33
# 2209                                          法网恢恢，疏而不漏  2018-11-18 00:14:29
# 2210                                           不会又是情杀吧！  2018-11-18 00:14:29
# 2211                                            枪毙没商量！😡  2018-11-18 00:14:28
# 2212                            哎，花样年华命不该绝啊，阎王大人可否网开一面？  2018-11-18 00:14:28
# 2213                                              总算抓到了  2018-11-18 00:14:27
# 2214                                             枪毙10分钟  2018-11-18 00:14:27
# 2215                                                毙了！  2018-11-18 00:14:27
# 2216                                      我靠！居然是他杀！禽兽啊！  2018-11-18 00:14:26
# 2217                                             姑娘一路走好  2018-11-18 00:14:26
# 2218                                         哇，不是摔死的。。。  2018-11-18 00:14:26
# 2219                                                 天哪  2018-11-18 00:14:25
# 2220                                               可悲可叹  2018-11-18 00:14:23
# 2221                                          天网恢恢 疏而不漏  2018-11-18 00:14:22
# 2222                                            为什么杀人呢？  2018-11-18 00:14:19
# 2223                                               哎...  2018-11-18 00:14:19
# 2224                                             早日公布真相  2018-11-18 00:14:17
# 2225                                                真可恶  2018-11-18 00:14:17
# 2226                                              绳之以法!  2018-11-18 00:14:13
# 2227                                                 呵呵  2018-11-18 00:14:13
# 2228                                              厉害，不错  2018-11-18 00:14:11
# 2229                                            广西壮族自治区  2018-11-18 00:14:05
# 2230                                              严惩！！！  2018-11-18 00:14:01
# 2231                                                不好说  2018-11-18 00:13:59
# 2232                                               奸杀了？  2018-11-18 00:13:57
#
#       favCounts  isDels  is_anonymous  shareCounts siteNames sources  \
# 0             0   False          True            0        网易      ph
# 1             0   False         False            0        网易      wb
# 2             0   False         False            0        网易      ph
# 3            12   False         False            0        网易      ph
# 4             0   False         False            0        网易      ph
# 5             0   False         False            0        网易      ph
# 6             0   False          True            0        网易      ph
# 7             0   False         False            0        网易      ph
# 8             0   False          True            0        网易      ph
# 9             1   False          True            0        网易      ph
# 10            0   False         False            0        网易      wb
# 11            0   False         False            0        网易      ph
# 12            0   False         False            0        网易      wb
# 13            0   False          True            0        网易      ph
# 14            0   False         False            0        网易      ph
# 15            0   False         False            0        网易      ph
# 16            0   False          True            0        网易      ph
# 17            0   False         False            0        网易      ph
# 18            0   False          True            0        网易      ph
# 19            0   False         False            0        网易      ph
# 20            0   False         False            0        网易      wb
# 21            0   False          True            0        网易      ph
# 22            0   False         False            0        网易      ph
# 23            0   False         False            0        网易      ph
# 24            0   False          True            0        网易      ph
# 25            0   False          True            0        网易      ph
# 26            0   False         False            0        网易      wb
# 27            0   False         False            0        网易      ph
# 28            0   False         False            0        网易      ph
# 29            0   False         False            0        网易      wb
# ...         ...     ...           ...          ...       ...     ...
# 2203          0   False         False            0        网易      ph
# 2204          0   False         False            0        网易      ph
# 2205          0   False         False            0        网易      ph
# 2206          0   False         False            0        网易      ph
# 2207          0   False         False            0        网易      ph
# 2208          0   False         False            0        网易      ph
# 2209          0   False         False            0        网易      ph
# 2210          0   False          True            0        网易      ph
# 2211          0   False          True            0        网易      ph
# 2212          0   False          True            0        网易      ph
# 2213          0   False         False            0        网易      ph
# 2214          0   False         False            0        网易      ph
# 2215          0   False         False            0        网易      ph
# 2216          0   False         False            0        网易      ph
# 2217          0   False         False            0        网易      ph
# 2218          0   False         False            0        网易      ph
# 2219          0   False         False            0        网易      ph
# 2220          0   False         False            0        网易      ph
# 2221          0   False          True            0        网易      ph
# 2222          0   False         False            0        网易      ph
# 2223          0   False         False            0        网易      ph
# 2224          0   False         False            0        网易      ph
# 2225          0   False         False            0        网易      ph
# 2226          0   False         False            0        网易      ph
# 2227          0   False         False            0        网易      ph
# 2228          0   False         False            0        网易      ph
# 2229          0   False          True            0        网易      ph
# 2230          0   False         False            0        网易      ph
# 2231          0   False         False            0        网易      ph
# 2232          0   False          True            0        网易      ph
#
#        user_IDs user_locations  votes
# 0             0            安徽省      0
# 1        989789          广东省深圳     20
# 2     107368171         广东省佛山市      1
# 3     125943715         广东省清远市   4417
# 4        504719         广东省深圳市      0
# 5      17451673          浙江省绍兴      1
# 6             0         辽宁省沈阳市      0
# 7       9248336         广东省广州市      2
# 8             0          浙江省杭州      0
# 9             0          浙江省宁波   1035
# 10      4213156          湖北省十堰      0
# 11    102937265         北京市海淀区     28
# 12    117091331          山东省临沂      0
# 13            0        上海市浦东新区      4
# 14    122845690            北京市     68
# 15    125943715         广东省清远市      0
# 16            0         浙江省嘉兴市   3108
# 17    102937265         北京市海淀区      2
# 18            0         四川省成都市      0
# 19     60155377            浙江省      0
# 20    110727231          山东省临沂      0
# 21            0         四川省成都市      2
# 22       540707            重庆市      0
# 23    260786545          辽宁省鞍山   1601
# 24            0          浙江省杭州      0
# 25            0          浙江省杭州      0
# 26       569497         上海市普陀区      1
# 27    259430804          湖北省荆门      0
# 28     42851662         浙江省杭州市   2019
# 29       569497         上海市普陀区      1
# ...         ...            ...    ...
# 2203     334525            山东省      0
# 2204  121508542         浙江省台州市      0
# 2205   81981666         江苏省无锡市      0
# 2206   45838016         浙江省杭州市      0
# 2207  127991370         浙江省杭州市      0
# 2208   71147703          浙江省杭州      0
# 2209  125930552         江苏省南京市      0
# 2210          0         浙江省杭州市      0
# 2211          0          福建省厦门      0
# 2212          0         北京市海淀区      0
# 2213  265054479          江苏省盐城      0
# 2214   57785579         浙江省杭州市      0
# 2215  108409676      广西壮族自治区南宁      0
# 2216   60385844         浙江省杭州市      0
# 2217  110868814         浙江省金华市      0
# 2218  105260741         江苏省苏州市      0
# 2219  108105225         浙江省杭州市      0
# 2220    1375814        黑龙江省绥化市      0
# 2221          0          福建省泉州      0
# 2222   49462204         浙江省杭州市      0
# 2223  111849462          浙江省杭州      0
# 2224    8305989         浙江省绍兴市      0
# 2225   64003424         浙江省杭州市      0
# 2226  105989474         上海市宝山区      0
# 2227   96928529          浙江省杭州      0
# 2228    2154714         河南省郑州市      0
# 2229          0         广东省惠州市      0
# 2230  103000925            上海市      0
# 2231   79468475          四川省成都      0
# 2232          0         辽宁省大连市      0
#
# [2233 rows x 15 columns]
